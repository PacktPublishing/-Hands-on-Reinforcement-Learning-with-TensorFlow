# %% [markdown]
# ### Loading the environment
#
# https://gym.openai.com/envs/Taxi-v2/

# %%
import gym
env = gym.make('Taxi-v2')

# %% [markdown]
# ### Initialization and rendering

# %%
initial_state = env.reset()
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# ### Q-learning Hyperparameters

# %%
alpha = 0.1
gamma = 0.6
epsilon = 0.8

# %% [markdown]
# ### Initializing the Q-table

# %%
import numpy as np
from collections import defaultdict

# Ideally, the size of Q-table is state_space_size x action_space_size
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# %% [markdown]
# ### Updating the Q-values after every epoch
#
# ![https://s31.postimg.cc/tmim26kqx/q_learning_equation.png](https://s31.postimg.cc/tmim26kqx/q_learning_equation.png?dl=1)

# %%
def q_learning_update(q_table, env, state, epsilon):
    """
    Updates the Q-values according to the Q-learning equation.
    """
    if random.uniform(0, 1) > epsilon:
        action = env.action_space.sample() # select a random action
    else:
        action = select_optimal_action(q_table, state) # select an optimal action
    
    next_state, reward, done, _ = env.step(action)
    old_q_value = q_table[state][action]


    # Maximum q_value for the actions in next state
    next_max = np.max(q_table[next_state])

    new_q_value = (1 - alpha) * old_q_value + alpha * (reward + gamma * next_max)

    # Update the q_value
    q_table[state][action] = new_q_value

    return next_state, reward, done

# %%
import random

def select_optimal_action(q_table, state):
    """
    Given a state, select the action from the action space having the
    highest Q-value in the q_table.
    """
    if np.sum(q_table[state]) == 0:
        return random.randint(0, q_table.shape[1]-1)
    
    return np.argmax(q_table[state])

# %%
def train_agent(q_table, env, num_episodes, epsilon):
    for i in range(num_episodes):
        state = env.reset()

        epochs = 0
        num_penalties, total_reward = 0, 0
        
        done = False
        
        while not done:
            state, reward, done = q_learning_update(q_table, env, state, epsilon)
            total_reward += reward

            if reward == -10:
                num_penalties += 1

            epochs += 1
        print("\nTraining episode {}".format(i + 1))
        print("Time steps: {}, Penalties: {}, Reward: {}".format(epochs,
                                                                 num_penalties,
                                                                 total_reward))

    print("Training finished.\n")
    return q_table

# %% [markdown]
# ### Let's train

# %%
q_table = train_agent(q_table, env, 5000, epsilon)
# Out:
# Training episode 1
# Time steps: 200, Penalties: 46, Reward: -614
#
# Training episode 2
# Time steps: 200, Penalties: 23, Reward: -407
#
# Training episode 3
# Time steps: 200, Penalties: 45, Reward: -605
#
# Training episode 4
# Time steps: 200, Penalties: 43, Reward: -587
#
# Training episode 5
# Time steps: 200, Penalties: 39, Reward: -551
#
# Training episode 6
# Time steps: 200, Penalties: 38, Reward: -542
#
# Training episode 7
# Time steps: 200, Penalties: 50, Reward: -650
#
# Training episode 8
# Time steps: 200, Penalties: 41, Reward: -569
#
# Training episode 9
# Time steps: 200, Penalties: 39, Reward: -551
#
# Training episode 10
# Time steps: 200, Penalties: 51, Reward: -659
#
# Training episode 11
# Time steps: 200, Penalties: 41, Reward: -569
#
# Training episode 12
# Time steps: 200, Penalties: 45, Reward: -605
#
# Training episode 13
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 14
# Time steps: 200, Penalties: 40, Reward: -560
#
# Training episode 15
# Time steps: 142, Penalties: 14, Reward: -247
#
# Training episode 16
# Time steps: 200, Penalties: 26, Reward: -434
#
# Training episode 17
# Time steps: 200, Penalties: 47, Reward: -623
#
# Training episode 18
# Time steps: 188, Penalties: 41, Reward: -536
#
# Training episode 19
# Time steps: 52, Penalties: 3, Reward: -58
#
# Training episode 20
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 21
# Time steps: 199, Penalties: 29, Reward: -439
#
# Training episode 22
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 23
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 24
# Time steps: 200, Penalties: 20, Reward: -380
#
# Training episode 25
# Time steps: 200, Penalties: 48, Reward: -632
#
# Training episode 26
# Time steps: 200, Penalties: 21, Reward: -389
#
# Training episode 27
# Time steps: 200, Penalties: 5, Reward: -245
#
# Training episode 28
# Time steps: 200, Penalties: 28, Reward: -452
#
# Training episode 29
# Time steps: 200, Penalties: 26, Reward: -434
#
# Training episode 30
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 31
# Time steps: 200, Penalties: 30, Reward: -470
#
# Training episode 32
# Time steps: 200, Penalties: 20, Reward: -380
#
# Training episode 33
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 34
# Time steps: 200, Penalties: 26, Reward: -434
#
# Training episode 35
# Time steps: 200, Penalties: 43, Reward: -587
#
# Training episode 36
# Time steps: 118, Penalties: 22, Reward: -295
#
# Training episode 37
# Time steps: 171, Penalties: 24, Reward: -366
#
# Training episode 38
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 39
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 40
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 41
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 42
# Time steps: 200, Penalties: 20, Reward: -380
#
# Training episode 43
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 44
# Time steps: 71, Penalties: 4, Reward: -86
#
# Training episode 45
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 46
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 47
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 48
# Time steps: 144, Penalties: 7, Reward: -186
#
# Training episode 49
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 50
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 51
# Time steps: 120, Penalties: 8, Reward: -171
#
# Training episode 52
# Time steps: 200, Penalties: 20, Reward: -380
#
# Training episode 53
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 54
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 55
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 56
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 57
# Time steps: 63, Penalties: 3, Reward: -69
#
# Training episode 58
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 59
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 60
# Time steps: 62, Penalties: 4, Reward: -77
#
# Training episode 61
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 62
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 63
# Time steps: 92, Penalties: 10, Reward: -161
#
# Training episode 64
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 65
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 66
# Time steps: 200, Penalties: 21, Reward: -389
#
# Training episode 67
# Time steps: 200, Penalties: 6, Reward: -254
#
# Training episode 68
# Time steps: 34, Penalties: 2, Reward: -31
#
# Training episode 69
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 70
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 71
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 72
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 73
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 74
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 75
# Time steps: 192, Penalties: 9, Reward: -252
#
# Training episode 76
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 77
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 78
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 79
# Time steps: 200, Penalties: 22, Reward: -398
#
# Training episode 80
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 81
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 82
# Time steps: 150, Penalties: 12, Reward: -237
#
# Training episode 83
# Time steps: 73, Penalties: 4, Reward: -88
#
# Training episode 84
# Time steps: 198, Penalties: 10, Reward: -267
#
# Training episode 85
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 86
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 87
# Time steps: 81, Penalties: 1, Reward: -69
#
# Training episode 88
# Time steps: 200, Penalties: 22, Reward: -398
#
# Training episode 89
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 90
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 91
# Time steps: 191, Penalties: 14, Reward: -296
#
# Training episode 92
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 93
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 94
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 95
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 96
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 97
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 98
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 99
# Time steps: 200, Penalties: 7, Reward: -263
#
# Training episode 100
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 101
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 102
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 103
# Time steps: 198, Penalties: 13, Reward: -294
#
# Training episode 104
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 105
# Time steps: 38, Penalties: 1, Reward: -26
#
# Training episode 106
# Time steps: 176, Penalties: 5, Reward: -200
#
# Training episode 107
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 108
# Time steps: 159, Penalties: 5, Reward: -183
#
# Training episode 109
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 110
# Time steps: 40, Penalties: 4, Reward: -55
#
# Training episode 111
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 112
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 113
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 114
# Time steps: 107, Penalties: 12, Reward: -194
#
# Training episode 115
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 116
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 117
# Time steps: 191, Penalties: 12, Reward: -278
#
# Training episode 118
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 119
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 120
# Time steps: 120, Penalties: 10, Reward: -189
#
# Training episode 121
# Time steps: 200, Penalties: 7, Reward: -263
#
# Training episode 122
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 123
# Time steps: 127, Penalties: 10, Reward: -196
#
# Training episode 124
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 125
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 126
# Time steps: 164, Penalties: 18, Reward: -305
#
# Training episode 127
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 128
# Time steps: 117, Penalties: 7, Reward: -159
#
# Training episode 129
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 130
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 131
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 132
# Time steps: 175, Penalties: 8, Reward: -226
#
# Training episode 133
# Time steps: 109, Penalties: 10, Reward: -178
#
# Training episode 134
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 135
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 136
# Time steps: 165, Penalties: 8, Reward: -216
#
# Training episode 137
# Time steps: 172, Penalties: 7, Reward: -214
#
# Training episode 138
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 139
# Time steps: 200, Penalties: 20, Reward: -380
# Training episode 140
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 141
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 142
# Time steps: 149, Penalties: 13, Reward: -245
#
# Training episode 143
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 144
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 145
# Time steps: 156, Penalties: 4, Reward: -171
#
# Training episode 146
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 147
# Time steps: 42, Penalties: 4, Reward: -57
#
# Training episode 148
# Time steps: 47, Penalties: 1, Reward: -35
#
# Training episode 149
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 150
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 151
# Time steps: 92, Penalties: 4, Reward: -107
#
# Training episode 152
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 153
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 154
# Time steps: 120, Penalties: 7, Reward: -162
#
# Training episode 155
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 156
# Time steps: 170, Penalties: 7, Reward: -212
#
# Training episode 157
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 158
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 159
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 160
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 161
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 162
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 163
# Time steps: 200, Penalties: 23, Reward: -407
#
# Training episode 164
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 165
# Time steps: 46, Penalties: 3, Reward: -52
#
# Training episode 166
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 167
# Time steps: 138, Penalties: 9, Reward: -198
#
# Training episode 168
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 169
# Time steps: 200, Penalties: 7, Reward: -263
#
# Training episode 170
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 171
# Time steps: 192, Penalties: 14, Reward: -297
#
# Training episode 172
# Time steps: 89, Penalties: 4, Reward: -104
#
# Training episode 173
# Time steps: 50, Penalties: 1, Reward: -38
#
# Training episode 174
# Time steps: 200, Penalties: 21, Reward: -389
#
# Training episode 175
# Time steps: 53, Penalties: 5, Reward: -77
#
# Training episode 176
# Time steps: 106, Penalties: 3, Reward: -112
#
# Training episode 177
# Time steps: 180, Penalties: 6, Reward: -213
#
# Training episode 178
# Time steps: 151, Penalties: 8, Reward: -202
#
# Training episode 179
# Time steps: 128, Penalties: 7, Reward: -170
#
# Training episode 180
# Time steps: 200, Penalties: 20, Reward: -380
#
# Training episode 181
# Time steps: 195, Penalties: 9, Reward: -255
#
# Training episode 182
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 183
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 184
# Time steps: 200, Penalties: 7, Reward: -263
#
# Training episode 185
# Time steps: 16, Penalties: 2, Reward: -13
#
# Training episode 186
# Time steps: 132, Penalties: 10, Reward: -201
#
# Training episode 187
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 188
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 189
# Time steps: 99, Penalties: 13, Reward: -195
#
# Training episode 190
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 191
# Time steps: 194, Penalties: 16, Reward: -317
#
# Training episode 192
# Time steps: 52, Penalties: 4, Reward: -67
#
# Training episode 193
# Time steps: 134, Penalties: 6, Reward: -167
#
# Training episode 194
# Time steps: 200, Penalties: 20, Reward: -380
#
# Training episode 195
# Time steps: 97, Penalties: 4, Reward: -112
#
# Training episode 196
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 197
# Time steps: 160, Penalties: 4, Reward: -175
#
# Training episode 198
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 199
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 200
# Time steps: 103, Penalties: 7, Reward: -145
#
# Training episode 201
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 202
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 203
# Time steps: 146, Penalties: 14, Reward: -251
#
# Training episode 204
# Time steps: 89, Penalties: 6, Reward: -122
#
# Training episode 205
# Time steps: 96, Penalties: 10, Reward: -165
#
# Training episode 206
# Time steps: 79, Penalties: 4, Reward: -94
#
# Training episode 207
# Time steps: 52, Penalties: 2, Reward: -49
#
# Training episode 208
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 209
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 210
# Time steps: 56, Penalties: 8, Reward: -107
#
# Training episode 211
# Time steps: 147, Penalties: 9, Reward: -207
#
# Training episode 212
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 213
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 214
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 215
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 216
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 217
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 218
# Time steps: 189, Penalties: 6, Reward: -222
#
# Training episode 219
# Time steps: 168, Penalties: 15, Reward: -282
#
# Training episode 220
# Time steps: 93, Penalties: 6, Reward: -126
#
# Training episode 221
# Time steps: 115, Penalties: 7, Reward: -157
#
# Training episode 222
# Time steps: 121, Penalties: 8, Reward: -172
#
# Training episode 223
# Time steps: 163, Penalties: 10, Reward: -232
#
# Training episode 224
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 225
# Time steps: 171, Penalties: 8, Reward: -222
#
# Training episode 226
# Time steps: 176, Penalties: 12, Reward: -263
#
# Training episode 227
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 228
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 229
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 230
# Time steps: 123, Penalties: 5, Reward: -147
#
# Training episode 231
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 232
# Time steps: 120, Penalties: 8, Reward: -171
#
# Training episode 233
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 234
# Time steps: 73, Penalties: 5, Reward: -97
#
# Training episode 235
# Time steps: 46, Penalties: 4, Reward: -61
#
# Training episode 236
# Time steps: 105, Penalties: 7, Reward: -147
#
# Training episode 237
# Time steps: 200, Penalties: 7, Reward: -263
#
# Training episode 238
# Time steps: 101, Penalties: 8, Reward: -152
#
# Training episode 239
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 240
# Time steps: 21, Penalties: 2, Reward: -18
#
# Training episode 241
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 242
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 243
# Time steps: 154, Penalties: 9, Reward: -214
#
# Training episode 244
# Time steps: 97, Penalties: 6, Reward: -130
#
# Training episode 245
# Time steps: 56, Penalties: 2, Reward: -53
#
# Training episode 246
# Time steps: 143, Penalties: 15, Reward: -257
#
# Training episode 247
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 248
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 249
# Time steps: 128, Penalties: 6, Reward: -161
#
# Training episode 250
# Time steps: 32, Penalties: 2, Reward: -29
#
# Training episode 251
# Time steps: 171, Penalties: 12, Reward: -258
#
# Training episode 252
# Time steps: 84, Penalties: 11, Reward: -162
#
# Training episode 253
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 254
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 255
# Time steps: 106, Penalties: 7, Reward: -148
#
# Training episode 256
# Time steps: 179, Penalties: 10, Reward: -248
#
# Training episode 257
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 258
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 259
# Time steps: 105, Penalties: 3, Reward: -111
#
# Training episode 260
# Time steps: 40, Penalties: 1, Reward: -28
#
# Training episode 261
# Time steps: 181, Penalties: 10, Reward: -250
#
# Training episode 262
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 263
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 264
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 265
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 266
# Time steps: 39, Penalties: 0, Reward: -18
#
# Training episode 267
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 268
# Time steps: 112, Penalties: 4, Reward: -127
#
# Training episode 269
# Time steps: 172, Penalties: 11, Reward: -250
#
# Training episode 270
# Time steps: 68, Penalties: 6, Reward: -101
#
# Training episode 271
# Time steps: 129, Penalties: 8, Reward: -180
#
# Training episode 272
# Time steps: 101, Penalties: 10, Reward: -170
#
# Training episode 273
# Time steps: 200, Penalties: 15, Reward: -335
# Training episode 274
# Time steps: 89, Penalties: 5, Reward: -113
#
# Training episode 275
# Time steps: 46, Penalties: 2, Reward: -43
#
# Training episode 276
# Time steps: 40, Penalties: 4, Reward: -55
#
# Training episode 277
# Time steps: 30, Penalties: 2, Reward: -27
#
# Training episode 278
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 279
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 280
# Time steps: 119, Penalties: 3, Reward: -125
#
# Training episode 281
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 282
# Time steps: 96, Penalties: 5, Reward: -120
#
# Training episode 283
# Time steps: 176, Penalties: 12, Reward: -263
#
# Training episode 284
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 285
# Time steps: 82, Penalties: 7, Reward: -124
#
# Training episode 286
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 287
# Time steps: 137, Penalties: 10, Reward: -206
#
# Training episode 288
# Time steps: 200, Penalties: 17, Reward: -332
#
# Training episode 289
# Time steps: 119, Penalties: 5, Reward: -143
#
# Training episode 290
# Time steps: 171, Penalties: 10, Reward: -240
#
# Training episode 291
# Time steps: 200, Penalties: 7, Reward: -263
#
# Training episode 292
# Time steps: 61, Penalties: 4, Reward: -76
#
# Training episode 293
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 294
# Time steps: 191, Penalties: 13, Reward: -287
#
# Training episode 295
# Time steps: 67, Penalties: 3, Reward: -73
#
# Training episode 296
# Time steps: 171, Penalties: 13, Reward: -267
#
# Training episode 297
# Time steps: 38, Penalties: 1, Reward: -26
#
# Training episode 298
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 299
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 300
# Time steps: 143, Penalties: 10, Reward: -212
#
# Training episode 301
# Time steps: 91, Penalties: 8, Reward: -142
#
# Training episode 302
# Time steps: 195, Penalties: 16, Reward: -318
#
# Training episode 303
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 304
# Time steps: 137, Penalties: 4, Reward: -152
#
# Training episode 305
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 306
# Time steps: 101, Penalties: 6, Reward: -134
#
# Training episode 307
# Time steps: 41, Penalties: 2, Reward: -38
#
# Training episode 308
# Time steps: 88, Penalties: 6, Reward: -121
#
# Training episode 309
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 310
# Time steps: 120, Penalties: 5, Reward: -144
#
# Training episode 311
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 312
# Time steps: 164, Penalties: 8, Reward: -215
#
# Training episode 313
# Time steps: 59, Penalties: 6, Reward: -92
#
# Training episode 314
# Time steps: 109, Penalties: 7, Reward: -151
#
# Training episode 315
# Time steps: 128, Penalties: 10, Reward: -197
#
# Training episode 316
# Time steps: 200, Penalties: 9, Reward: -281
#
# Training episode 317
# Time steps: 166, Penalties: 9, Reward: -226
#
# Training episode 318
# Time steps: 89, Penalties: 4, Reward: -104
#
# Training episode 319
# Time steps: 130, Penalties: 11, Reward: -208
#
# Training episode 320
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 321
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 322
# Time steps: 102, Penalties: 11, Reward: -180
#
# Training episode 323
# Time steps: 37, Penalties: 1, Reward: -25
#
# Training episode 324
# Time steps: 145, Penalties: 10, Reward: -214
#
# Training episode 325
# Time steps: 163, Penalties: 12, Reward: -250
#
# Training episode 326
# Time steps: 167, Penalties: 7, Reward: -209
#
# Training episode 327
# Time steps: 197, Penalties: 20, Reward: -356
#
# Training episode 328
# Time steps: 96, Penalties: 8, Reward: -147
#
# Training episode 329
# Time steps: 100, Penalties: 5, Reward: -124
#
# Training episode 330
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 331
# Time steps: 92, Penalties: 13, Reward: -188
#
# Training episode 332
# Time steps: 40, Penalties: 3, Reward: -46
#
# Training episode 333
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 334
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 335
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 336
# Time steps: 74, Penalties: 6, Reward: -107
#
# Training episode 337
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 338
# Time steps: 50, Penalties: 1, Reward: -38
#
# Training episode 339
# Time steps: 138, Penalties: 9, Reward: -198
#
# Training episode 340
# Time steps: 186, Penalties: 10, Reward: -255
#
# Training episode 341
# Time steps: 81, Penalties: 3, Reward: -87
#
# Training episode 342
# Time steps: 166, Penalties: 11, Reward: -244
#
# Training episode 343
# Time steps: 112, Penalties: 6, Reward: -145
#
# Training episode 344
# Time steps: 15, Penalties: 0, Reward: 6
#
# Training episode 345
# Time steps: 143, Penalties: 5, Reward: -167
#
# Training episode 346
# Time steps: 156, Penalties: 9, Reward: -216
#
# Training episode 347
# Time steps: 70, Penalties: 6, Reward: -103
#
# Training episode 348
# Time steps: 188, Penalties: 11, Reward: -266
#
# Training episode 349
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 350
# Time steps: 23, Penalties: 2, Reward: -20
#
# Training episode 351
# Time steps: 97, Penalties: 4, Reward: -112
#
# Training episode 352
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 353
# Time steps: 45, Penalties: 4, Reward: -60
#
# Training episode 354
# Time steps: 152, Penalties: 8, Reward: -203
#
# Training episode 355
# Time steps: 132, Penalties: 7, Reward: -174
#
# Training episode 356
# Time steps: 185, Penalties: 15, Reward: -299
#
# Training episode 357
# Time steps: 107, Penalties: 5, Reward: -131
#
# Training episode 358
# Time steps: 170, Penalties: 9, Reward: -230
#
# Training episode 359
# Time steps: 177, Penalties: 11, Reward: -255
#
# Training episode 360
# Time steps: 33, Penalties: 1, Reward: -21
#
# Training episode 361
# Time steps: 153, Penalties: 12, Reward: -240
#
# Training episode 362
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 363
# Time steps: 173, Penalties: 8, Reward: -224
#
# Training episode 364
# Time steps: 23, Penalties: 2, Reward: -20
#
# Training episode 365
# Time steps: 132, Penalties: 13, Reward: -228
#
# Training episode 366
# Time steps: 196, Penalties: 6, Reward: -229
#
# Training episode 367
# Time steps: 156, Penalties: 7, Reward: -198
#
# Training episode 368
# Time steps: 8, Penalties: 0, Reward: 13
#
# Training episode 369
# Time steps: 181, Penalties: 9, Reward: -241
#
# Training episode 370
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 371
# Time steps: 81, Penalties: 4, Reward: -96
#
# Training episode 372
# Time steps: 120, Penalties: 10, Reward: -189
#
# Training episode 373
# Time steps: 79, Penalties: 5, Reward: -103
#
# Training episode 374
# Time steps: 65, Penalties: 3, Reward: -71
#
# Training episode 375
# Time steps: 200, Penalties: 11, Reward: -299
#
# Training episode 376
# Time steps: 146, Penalties: 8, Reward: -197
#
# Training episode 377
# Time steps: 166, Penalties: 6, Reward: -199
#
# Training episode 378
# Time steps: 25, Penalties: 0, Reward: -4
#
# Training episode 379
# Time steps: 156, Penalties: 15, Reward: -270
#
# Training episode 380
# Time steps: 95, Penalties: 5, Reward: -119
#
# Training episode 381
# Time steps: 166, Penalties: 15, Reward: -280
#
# Training episode 382
# Time steps: 200, Penalties: 8, Reward: -272
#
# Training episode 383
# Time steps: 32, Penalties: 3, Reward: -38
#
# Training episode 384
# Time steps: 99, Penalties: 6, Reward: -132
#
# Training episode 385
# Time steps: 144, Penalties: 12, Reward: -231
#
# Training episode 386
# Time steps: 154, Penalties: 10, Reward: -223
#
# Training episode 387
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 388
# Time steps: 152, Penalties: 16, Reward: -275
#
# Training episode 389
# Time steps: 26, Penalties: 1, Reward: -14
#
# Training episode 390
# Time steps: 47, Penalties: 2, Reward: -44
#
# Training episode 391
# Time steps: 188, Penalties: 14, Reward: -293
#
# Training episode 392
# Time steps: 76, Penalties: 6, Reward: -109
#
# Training episode 393
# Time steps: 97, Penalties: 3, Reward: -103
#
# Training episode 394
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 395
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 396
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 397
# Time steps: 120, Penalties: 13, Reward: -216
#
# Training episode 398
# Time steps: 200, Penalties: 7, Reward: -242
#
# Training episode 399
# Time steps: 196, Penalties: 13, Reward: -292
#
# Training episode 400
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 401
# Time steps: 79, Penalties: 4, Reward: -94
#
# Training episode 402
# Time steps: 200, Penalties: 19, Reward: -371
#
# Training episode 403
# Time steps: 97, Penalties: 4, Reward: -112
#
# Training episode 404
# Time steps: 101, Penalties: 9, Reward: -161
#
# Training episode 405
# Time steps: 70, Penalties: 2, Reward: -67
#
# Training episode 406
# Time steps: 181, Penalties: 17, Reward: -313
#
# Training episode 407
# Time steps: 32, Penalties: 2, Reward: -29
#
# Training episode 408
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 409
# Time steps: 53, Penalties: 3, Reward: -59
#
# Training episode 410
# Time steps: 65, Penalties: 3, Reward: -71
#
# Training episode 411
# Time steps: 180, Penalties: 9, Reward: -240
#
# Training episode 412
# Time steps: 84, Penalties: 3, Reward: -90
#
# Training episode 413
# Time steps: 159, Penalties: 9, Reward: -219
#
# Training episode 414
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 415
# Time steps: 168, Penalties: 9, Reward: -228
#
# Training episode 416
# Time steps: 44, Penalties: 5, Reward: -68
#
# Training episode 417
# Time steps: 91, Penalties: 3, Reward: -97
#
# Training episode 418
# Time steps: 87, Penalties: 8, Reward: -138
#
# Training episode 419
# Time steps: 27, Penalties: 1, Reward: -15
#
# Training episode 420
# Time steps: 126, Penalties: 10, Reward: -195
#
# Training episode 421
# Time steps: 200, Penalties: 11, Reward: -278
#
# Training episode 422
# Time steps: 71, Penalties: 1, Reward: -59
#
# Training episode 423
# Time steps: 109, Penalties: 5, Reward: -133
#
# Training episode 424
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 425
# Time steps: 200, Penalties: 12, Reward: -308
#
# Training episode 426
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 427
# Time steps: 75, Penalties: 5, Reward: -99
#
# Training episode 428
# Time steps: 112, Penalties: 6, Reward: -145
#
# Training episode 429
# Time steps: 116, Penalties: 11, Reward: -194
#
# Training episode 430
# Time steps: 73, Penalties: 6, Reward: -106
# Training episode 431
# Time steps: 130, Penalties: 10, Reward: -199
#
# Training episode 432
# Time steps: 51, Penalties: 2, Reward: -48
#
# Training episode 433
# Time steps: 175, Penalties: 11, Reward: -253
#
# Training episode 434
# Time steps: 74, Penalties: 5, Reward: -98
#
# Training episode 435
# Time steps: 142, Penalties: 8, Reward: -193
#
# Training episode 436
# Time steps: 25, Penalties: 2, Reward: -22
#
# Training episode 437
# Time steps: 75, Penalties: 3, Reward: -81
#
# Training episode 438
# Time steps: 11, Penalties: 1, Reward: 1
#
# Training episode 439
# Time steps: 167, Penalties: 5, Reward: -191
#
# Training episode 440
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 441
# Time steps: 155, Penalties: 11, Reward: -233
#
# Training episode 442
# Time steps: 159, Penalties: 10, Reward: -228
#
# Training episode 443
# Time steps: 134, Penalties: 13, Reward: -230
#
# Training episode 444
# Time steps: 115, Penalties: 7, Reward: -157
#
# Training episode 445
# Time steps: 42, Penalties: 5, Reward: -66
#
# Training episode 446
# Time steps: 79, Penalties: 1, Reward: -67
#
# Training episode 447
# Time steps: 155, Penalties: 15, Reward: -269
#
# Training episode 448
# Time steps: 60, Penalties: 0, Reward: -39
#
# Training episode 449
# Time steps: 131, Penalties: 10, Reward: -200
#
# Training episode 450
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 451
# Time steps: 123, Penalties: 8, Reward: -174
#
# Training episode 452
# Time steps: 95, Penalties: 9, Reward: -155
#
# Training episode 453
# Time steps: 28, Penalties: 3, Reward: -34
#
# Training episode 454
# Time steps: 93, Penalties: 3, Reward: -99
#
# Training episode 455
# Time steps: 74, Penalties: 5, Reward: -98
#
# Training episode 456
# Time steps: 67, Penalties: 7, Reward: -109
#
# Training episode 457
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 458
# Time steps: 51, Penalties: 4, Reward: -66
#
# Training episode 459
# Time steps: 95, Penalties: 6, Reward: -128
#
# Training episode 460
# Time steps: 85, Penalties: 4, Reward: -100
#
# Training episode 461
# Time steps: 99, Penalties: 8, Reward: -150
#
# Training episode 462
# Time steps: 115, Penalties: 7, Reward: -157
#
# Training episode 463
# Time steps: 40, Penalties: 3, Reward: -46
#
# Training episode 464
# Time steps: 200, Penalties: 10, Reward: -290
#
# Training episode 465
# Time steps: 140, Penalties: 11, Reward: -218
#
# Training episode 466
# Time steps: 8, Penalties: 0, Reward: 13
#
# Training episode 467
# Time steps: 25, Penalties: 1, Reward: -13
#
# Training episode 468
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 469
# Time steps: 69, Penalties: 8, Reward: -120
#
# Training episode 470
# Time steps: 32, Penalties: 2, Reward: -29
#
# Training episode 471
# Time steps: 120, Penalties: 8, Reward: -171
#
# Training episode 472
# Time steps: 69, Penalties: 4, Reward: -84
#
# Training episode 473
# Time steps: 54, Penalties: 2, Reward: -51
#
# Training episode 474
# Time steps: 34, Penalties: 1, Reward: -22
#
# Training episode 475
# Time steps: 165, Penalties: 11, Reward: -243
#
# Training episode 476
# Time steps: 45, Penalties: 1, Reward: -33
#
# Training episode 477
# Time steps: 173, Penalties: 7, Reward: -215
#
# Training episode 478
# Time steps: 89, Penalties: 4, Reward: -104
#
# Training episode 479
# Time steps: 151, Penalties: 10, Reward: -220
#
# Training episode 480
# Time steps: 186, Penalties: 14, Reward: -291
#
# Training episode 481
# Time steps: 142, Penalties: 13, Reward: -238
#
# Training episode 482
# Time steps: 124, Penalties: 4, Reward: -139
#
# Training episode 483
# Time steps: 163, Penalties: 12, Reward: -250
#
# Training episode 484
# Time steps: 166, Penalties: 8, Reward: -217
#
# Training episode 485
# Time steps: 142, Penalties: 11, Reward: -220
#
# Training episode 486
# Time steps: 200, Penalties: 15, Reward: -335
#
# Training episode 487
# Time steps: 131, Penalties: 11, Reward: -209
#
# Training episode 488
# Time steps: 67, Penalties: 7, Reward: -109
#
# Training episode 489
# Time steps: 156, Penalties: 13, Reward: -252
#
# Training episode 490
# Time steps: 157, Penalties: 17, Reward: -289
#
# Training episode 491
# Time steps: 111, Penalties: 8, Reward: -162
#
# Training episode 492
# Time steps: 71, Penalties: 6, Reward: -104
#
# Training episode 493
# Time steps: 78, Penalties: 3, Reward: -84
#
# Training episode 494
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 495
# Time steps: 112, Penalties: 7, Reward: -154
#
# Training episode 496
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 497
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 498
# Time steps: 60, Penalties: 2, Reward: -57
#
# Training episode 499
# Time steps: 104, Penalties: 8, Reward: -155
#
# Training episode 500
# Time steps: 200, Penalties: 13, Reward: -317
#
# Training episode 501
# Time steps: 84, Penalties: 5, Reward: -108
#
# Training episode 502
# Time steps: 155, Penalties: 7, Reward: -197
#
# Training episode 503
# Time steps: 75, Penalties: 7, Reward: -117
#
# Training episode 504
# Time steps: 23, Penalties: 1, Reward: -11
#
# Training episode 505
# Time steps: 102, Penalties: 9, Reward: -162
#
# Training episode 506
# Time steps: 8, Penalties: 0, Reward: 13
#
# Training episode 507
# Time steps: 144, Penalties: 8, Reward: -195
#
# Training episode 508
# Time steps: 20, Penalties: 2, Reward: -17
#
# Training episode 509
# Time steps: 78, Penalties: 4, Reward: -93
#
# Training episode 510
# Time steps: 63, Penalties: 2, Reward: -60
#
# Training episode 511
# Time steps: 26, Penalties: 2, Reward: -23
#
# Training episode 512
# Time steps: 133, Penalties: 14, Reward: -238
#
# Training episode 513
# Time steps: 41, Penalties: 2, Reward: -38
#
# Training episode 514
# Time steps: 185, Penalties: 5, Reward: -209
#
# Training episode 515
# Time steps: 105, Penalties: 4, Reward: -120
#
# Training episode 516
# Time steps: 78, Penalties: 3, Reward: -84
#
# Training episode 517
# Time steps: 119, Penalties: 10, Reward: -188
#
# Training episode 518
# Time steps: 125, Penalties: 5, Reward: -149
#
# Training episode 519
# Time steps: 51, Penalties: 2, Reward: -48
#
# Training episode 520
# Time steps: 34, Penalties: 3, Reward: -40
#
# Training episode 521
# Time steps: 96, Penalties: 6, Reward: -129
#
# Training episode 522
# Time steps: 108, Penalties: 11, Reward: -186
#
# Training episode 523
# Time steps: 83, Penalties: 5, Reward: -107
#
# Training episode 524
# Time steps: 50, Penalties: 4, Reward: -65
#
# Training episode 525
# Time steps: 171, Penalties: 15, Reward: -285
#
# Training episode 526
# Time steps: 56, Penalties: 3, Reward: -62
#
# Training episode 527
# Time steps: 121, Penalties: 6, Reward: -154
#
# Training episode 528
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 529
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 530
# Time steps: 143, Penalties: 8, Reward: -194
#
# Training episode 531
# Time steps: 200, Penalties: 16, Reward: -323
#
# Training episode 532
# Time steps: 48, Penalties: 1, Reward: -36
#
# Training episode 533
# Time steps: 48, Penalties: 1, Reward: -36
#
# Training episode 534
# Time steps: 59, Penalties: 2, Reward: -56
#
# Training episode 535
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 536
# Time steps: 39, Penalties: 2, Reward: -36
#
# Training episode 537
# Time steps: 30, Penalties: 0, Reward: -9
#
# Training episode 538
# Time steps: 67, Penalties: 6, Reward: -100
#
# Training episode 539
# Time steps: 160, Penalties: 8, Reward: -211
#
# Training episode 540
# Time steps: 100, Penalties: 6, Reward: -133
#
# Training episode 541
# Time steps: 130, Penalties: 14, Reward: -235
#
# Training episode 542
# Time steps: 154, Penalties: 12, Reward: -241
#
# Training episode 543
# Time steps: 23, Penalties: 2, Reward: -20
#
# Training episode 544
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 545
# Time steps: 73, Penalties: 4, Reward: -88
#
# Training episode 546
# Time steps: 172, Penalties: 19, Reward: -322
#
# Training episode 547
# Time steps: 128, Penalties: 8, Reward: -179
#
# Training episode 548
# Time steps: 43, Penalties: 0, Reward: -22
#
# Training episode 549
# Time steps: 80, Penalties: 2, Reward: -77
#
# Training episode 550
# Time steps: 88, Penalties: 7, Reward: -130
#
# Training episode 551
# Time steps: 129, Penalties: 10, Reward: -198
#
# Training episode 552
# Time steps: 178, Penalties: 15, Reward: -292
#
# Training episode 553
# Time steps: 92, Penalties: 3, Reward: -98
#
# Training episode 554
# Time steps: 56, Penalties: 4, Reward: -71
#
# Training episode 555
# Time steps: 30, Penalties: 0, Reward: -9
#
# Training episode 556
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 557
# Time steps: 45, Penalties: 5, Reward: -69
#
# Training episode 558
# Time steps: 61, Penalties: 4, Reward: -76
#
# Training episode 559
# Time steps: 125, Penalties: 11, Reward: -203
#
# Training episode 560
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 561
# Time steps: 82, Penalties: 5, Reward: -106
#
# Training episode 562
# Time steps: 146, Penalties: 12, Reward: -233
#
# Training episode 563
# Time steps: 126, Penalties: 8, Reward: -177
#
# Training episode 564
# Time steps: 58, Penalties: 5, Reward: -82
#
# Training episode 565
# Time steps: 200, Penalties: 21, Reward: -389
#
# Training episode 566
# Time steps: 26, Penalties: 0, Reward: -5
#
# Training episode 567
# Time steps: 93, Penalties: 8, Reward: -144
#
# Training episode 568
# Time steps: 157, Penalties: 18, Reward: -298
#
# Training episode 569
# Time steps: 162, Penalties: 12, Reward: -249
#
# Training episode 570
# Time steps: 102, Penalties: 5, Reward: -126
#
# Training episode 571
# Time steps: 177, Penalties: 10, Reward: -246
#
# Training episode 572
# Time steps: 70, Penalties: 9, Reward: -130
#
# Training episode 573
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 574
# Time steps: 66, Penalties: 4, Reward: -81
#
# Training episode 575
# Time steps: 81, Penalties: 5, Reward: -105
#
# Training episode 576
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 577
# Time steps: 43, Penalties: 2, Reward: -40
#
# Training episode 578
# Time steps: 126, Penalties: 11, Reward: -204
#
# Training episode 579
# Time steps: 88, Penalties: 3, Reward: -94
#
# Training episode 580
# Time steps: 172, Penalties: 11, Reward: -250
#
# Training episode 581
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 582
# Time steps: 156, Penalties: 10, Reward: -225
#
# Training episode 583
# Time steps: 59, Penalties: 3, Reward: -65
#
# Training episode 584
# Time steps: 66, Penalties: 1, Reward: -54
#
# Training episode 585
# Time steps: 86, Penalties: 8, Reward: -137
#
# Training episode 586
# Time steps: 91, Penalties: 7, Reward: -133
#
# Training episode 587
# Time steps: 10, Penalties: 2, Reward: -7
#
# Training episode 588
# Time steps: 200, Penalties: 16, Reward: -344
#
# Training episode 589
# Time steps: 66, Penalties: 7, Reward: -108
#
# Training episode 590
# Time steps: 104, Penalties: 6, Reward: -137
#
# Training episode 591
# Time steps: 111, Penalties: 10, Reward: -180
#
# Training episode 592
# Time steps: 29, Penalties: 2, Reward: -26
#
# Training episode 593
# Time steps: 44, Penalties: 0, Reward: -23
#
# Training episode 594
# Time steps: 90, Penalties: 7, Reward: -132
#
# Training episode 595
# Time steps: 87, Penalties: 5, Reward: -111
#
# Training episode 596
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 597
# Time steps: 40, Penalties: 2, Reward: -37
#
# Training episode 598
# Time steps: 66, Penalties: 4, Reward: -81
#
# Training episode 599
# Time steps: 87, Penalties: 6, Reward: -120
#
# Training episode 600
# Time steps: 39, Penalties: 3, Reward: -45
#
# Training episode 601
# Time steps: 148, Penalties: 9, Reward: -208
# Training episode 602
# Time steps: 25, Penalties: 1, Reward: -13
#
# Training episode 603
# Time steps: 140, Penalties: 7, Reward: -182
#
# Training episode 604
# Time steps: 64, Penalties: 6, Reward: -97
#
# Training episode 605
# Time steps: 92, Penalties: 14, Reward: -197
#
# Training episode 606
# Time steps: 31, Penalties: 2, Reward: -28
#
# Training episode 607
# Time steps: 60, Penalties: 4, Reward: -75
#
# Training episode 608
# Time steps: 78, Penalties: 3, Reward: -84
#
# Training episode 609
# Time steps: 31, Penalties: 2, Reward: -28
#
# Training episode 610
# Time steps: 41, Penalties: 4, Reward: -56
#
# Training episode 611
# Time steps: 165, Penalties: 10, Reward: -234
#
# Training episode 612
# Time steps: 54, Penalties: 4, Reward: -69
#
# Training episode 613
# Time steps: 177, Penalties: 13, Reward: -273
#
# Training episode 614
# Time steps: 47, Penalties: 2, Reward: -44
#
# Training episode 615
# Time steps: 64, Penalties: 8, Reward: -115
#
# Training episode 616
# Time steps: 38, Penalties: 2, Reward: -35
#
# Training episode 617
# Time steps: 122, Penalties: 6, Reward: -155
#
# Training episode 618
# Time steps: 103, Penalties: 4, Reward: -118
#
# Training episode 619
# Time steps: 75, Penalties: 4, Reward: -90
#
# Training episode 620
# Time steps: 122, Penalties: 5, Reward: -146
#
# Training episode 621
# Time steps: 15, Penalties: 0, Reward: 6
#
# Training episode 622
# Time steps: 73, Penalties: 6, Reward: -106
#
# Training episode 623
# Time steps: 82, Penalties: 6, Reward: -115
#
# Training episode 624
# Time steps: 24, Penalties: 2, Reward: -21
#
# Training episode 625
# Time steps: 34, Penalties: 8, Reward: -85
#
# Training episode 626
# Time steps: 137, Penalties: 8, Reward: -188
#
# Training episode 627
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 628
# Time steps: 200, Penalties: 17, Reward: -353
#
# Training episode 629
# Time steps: 146, Penalties: 12, Reward: -233
#
# Training episode 630
# Time steps: 66, Penalties: 1, Reward: -54
#
# Training episode 631
# Time steps: 192, Penalties: 11, Reward: -270
#
# Training episode 632
# Time steps: 99, Penalties: 5, Reward: -123
#
# Training episode 633
# Time steps: 54, Penalties: 2, Reward: -51
#
# Training episode 634
# Time steps: 36, Penalties: 3, Reward: -42
#
# Training episode 635
# Time steps: 103, Penalties: 3, Reward: -109
#
# Training episode 636
# Time steps: 13, Penalties: 2, Reward: -10
#
# Training episode 637
# Time steps: 81, Penalties: 2, Reward: -78
#
# Training episode 638
# Time steps: 93, Penalties: 5, Reward: -117
#
# Training episode 639
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 640
# Time steps: 111, Penalties: 9, Reward: -171
#
# Training episode 641
# Time steps: 77, Penalties: 7, Reward: -119
#
# Training episode 642
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 643
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 644
# Time steps: 41, Penalties: 1, Reward: -29
#
# Training episode 645
# Time steps: 99, Penalties: 8, Reward: -150
#
# Training episode 646
# Time steps: 54, Penalties: 6, Reward: -87
#
# Training episode 647
# Time steps: 65, Penalties: 3, Reward: -71
#
# Training episode 648
# Time steps: 76, Penalties: 7, Reward: -118
#
# Training episode 649
# Time steps: 11, Penalties: 2, Reward: -8
#
# Training episode 650
# Time steps: 105, Penalties: 8, Reward: -156
#
# Training episode 651
# Time steps: 62, Penalties: 4, Reward: -77
#
# Training episode 652
# Time steps: 73, Penalties: 6, Reward: -106
#
# Training episode 653
# Time steps: 61, Penalties: 3, Reward: -67
#
# Training episode 654
# Time steps: 31, Penalties: 4, Reward: -46
#
# Training episode 655
# Time steps: 61, Penalties: 3, Reward: -67
#
# Training episode 656
# Time steps: 95, Penalties: 4, Reward: -110
#
# Training episode 657
# Time steps: 50, Penalties: 4, Reward: -65
#
# Training episode 658
# Time steps: 39, Penalties: 0, Reward: -18
#
# Training episode 659
# Time steps: 22, Penalties: 2, Reward: -19
#
# Training episode 660
# Time steps: 117, Penalties: 7, Reward: -159
#
# Training episode 661
# Time steps: 70, Penalties: 4, Reward: -85
#
# Training episode 662
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 663
# Time steps: 25, Penalties: 1, Reward: -13
#
# Training episode 664
# Time steps: 181, Penalties: 8, Reward: -232
#
# Training episode 665
# Time steps: 40, Penalties: 1, Reward: -28
#
# Training episode 666
# Time steps: 35, Penalties: 1, Reward: -23
#
# Training episode 667
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 668
# Time steps: 121, Penalties: 7, Reward: -163
#
# Training episode 669
# Time steps: 179, Penalties: 19, Reward: -329
#
# Training episode 670
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 671
# Time steps: 28, Penalties: 1, Reward: -16
#
# Training episode 672
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 673
# Time steps: 118, Penalties: 9, Reward: -178
#
# Training episode 674
# Time steps: 73, Penalties: 5, Reward: -97
#
# Training episode 675
# Time steps: 42, Penalties: 3, Reward: -48
#
# Training episode 676
# Time steps: 97, Penalties: 7, Reward: -139
#
# Training episode 677
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 678
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 679
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 680
# Time steps: 18, Penalties: 1, Reward: -6
#
# Training episode 681
# Time steps: 26, Penalties: 1, Reward: -14
#
# Training episode 682
# Time steps: 47, Penalties: 4, Reward: -62
#
# Training episode 683
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 684
# Time steps: 127, Penalties: 13, Reward: -223
#
# Training episode 685
# Time steps: 97, Penalties: 10, Reward: -166
#
# Training episode 686
# Time steps: 52, Penalties: 5, Reward: -76
#
# Training episode 687
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 688
# Time steps: 100, Penalties: 6, Reward: -133
#
# Training episode 689
# Time steps: 200, Penalties: 14, Reward: -326
#
# Training episode 690
# Time steps: 10, Penalties: 1, Reward: 2
#
# Training episode 691
# Time steps: 121, Penalties: 8, Reward: -172
#
# Training episode 692
# Time steps: 37, Penalties: 4, Reward: -52
#
# Training episode 693
# Time steps: 37, Penalties: 1, Reward: -25
#
# Training episode 694
# Time steps: 53, Penalties: 4, Reward: -68
#
# Training episode 695
# Time steps: 52, Penalties: 5, Reward: -76
#
# Training episode 696
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 697
# Time steps: 89, Penalties: 4, Reward: -104
#
# Training episode 698
# Time steps: 38, Penalties: 1, Reward: -26
#
# Training episode 699
# Time steps: 21, Penalties: 3, Reward: -27
#
# Training episode 700
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 701
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 702
# Time steps: 23, Penalties: 0, Reward: -2
#
# Training episode 703
# Time steps: 42, Penalties: 3, Reward: -48
#
# Training episode 704
# Time steps: 49, Penalties: 2, Reward: -46
#
# Training episode 705
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 706
# Time steps: 96, Penalties: 6, Reward: -129
#
# Training episode 707
# Time steps: 24, Penalties: 1, Reward: -12
#
# Training episode 708
# Time steps: 11, Penalties: 1, Reward: 1
#
# Training episode 709
# Time steps: 57, Penalties: 4, Reward: -72
#
# Training episode 710
# Time steps: 30, Penalties: 2, Reward: -27
#
# Training episode 711
# Time steps: 56, Penalties: 4, Reward: -71
#
# Training episode 712
# Time steps: 200, Penalties: 18, Reward: -362
#
# Training episode 713
# Time steps: 128, Penalties: 5, Reward: -152
#
# Training episode 714
# Time steps: 9, Penalties: 1, Reward: 3
#
# Training episode 715
# Time steps: 29, Penalties: 4, Reward: -44
#
# Training episode 716
# Time steps: 30, Penalties: 3, Reward: -36
#
# Training episode 717
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 718
# Time steps: 20, Penalties: 1, Reward: -8
#
# Training episode 719
# Time steps: 25, Penalties: 0, Reward: -4
#
# Training episode 720
# Time steps: 135, Penalties: 13, Reward: -231
#
# Training episode 721
# Time steps: 28, Penalties: 0, Reward: -7
#
# Training episode 722
# Time steps: 43, Penalties: 2, Reward: -40
#
# Training episode 723
# Time steps: 82, Penalties: 7, Reward: -124
#
# Training episode 724
# Time steps: 54, Penalties: 4, Reward: -69
#
# Training episode 725
# Time steps: 128, Penalties: 10, Reward: -197
#
# Training episode 726
# Time steps: 81, Penalties: 5, Reward: -105
#
# Training episode 727
# Time steps: 28, Penalties: 1, Reward: -16
#
# Training episode 728
# Time steps: 51, Penalties: 3, Reward: -57
#
# Training episode 729
# Time steps: 32, Penalties: 1, Reward: -20
#
# Training episode 730
# Time steps: 6, Penalties: 0, Reward: 15
#
# Training episode 731
# Time steps: 56, Penalties: 2, Reward: -53
#
# Training episode 732
# Time steps: 49, Penalties: 2, Reward: -46
#
# Training episode 733
# Time steps: 40, Penalties: 6, Reward: -73
#
# Training episode 734
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 735
# ...
#
# Training episode 4751
# Time steps: 22, Penalties: 2, Reward: -19
#
# Training episode 4752
# Time steps: 15, Penalties: 0, Reward: 6
#
# Training episode 4753
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4754
# Time steps: 18, Penalties: 1, Reward: -6
#
# Training episode 4755
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4756
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4757
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 4758
# Time steps: 8, Penalties: 0, Reward: 13
#
# Training episode 4759
# Time steps: 20, Penalties: 2, Reward: -17
#
# Training episode 4760
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4761
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4762
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4763
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4764
# Time steps: 29, Penalties: 2, Reward: -26
#
# Training episode 4765
# Time steps: 22, Penalties: 0, Reward: -1
#
# Training episode 4766
# Time steps: 11, Penalties: 2, Reward: -8
#
# Training episode 4767
# Time steps: 20, Penalties: 1, Reward: -8
#
# Training episode 4768
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4769
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4770
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4771
# Time steps: 17, Penalties: 2, Reward: -14
#
# Training episode 4772
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4773
# Time steps: 18, Penalties: 2, Reward: -15
#
# Training episode 4774
# Time steps: 18, Penalties: 1, Reward: -6
#
# Training episode 4775
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 4776
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4777
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4778
# Time steps: 22, Penalties: 0, Reward: -1
#
# Training episode 4779
# Time steps: 22, Penalties: 1, Reward: -10
#
# Training episode 4780
# Time steps: 18, Penalties: 1, Reward: -6
#
# Training episode 4781
# Time steps: 13, Penalties: 3, Reward: -19
#
# Training episode 4782
# Time steps: 16, Penalties: 2, Reward: -13
#
# Training episode 4783
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4784
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4785
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4786
# Time steps: 27, Penalties: 1, Reward: -15
#
# Training episode 4787
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4788
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4789
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4790
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4791
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4792
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4793
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 4794
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 4795
# Time steps: 15, Penalties: 0, Reward: 6
#
# Training episode 4796
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4797
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4798
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4799
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4800
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4801
# Time steps: 17, Penalties: 2, Reward: -14
#
# Training episode 4802
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 4803
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4804
# Time steps: 21, Penalties: 4, Reward: -36
#
# Training episode 4805
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4806
# Time steps: 12, Penalties: 2, Reward: -9
#
# Training episode 4807
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4808
# Time steps: 11, Penalties: 1, Reward: 1
#
# Training episode 4809
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4810
# Time steps: 15, Penalties: 2, Reward: -12
#
# Training episode 4811
# Time steps: 15, Penalties: 2, Reward: -12
#
# Training episode 4812
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4813
# Time steps: 16, Penalties: 2, Reward: -13
#
# Training episode 4814
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4815
# Time steps: 19, Penalties: 2, Reward: -16
#
# Training episode 4816
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4817
# Time steps: 23, Penalties: 2, Reward: -20
#
# Training episode 4818
# Time steps: 10, Penalties: 1, Reward: 2
# Training episode 4819
# Time steps: 18, Penalties: 2, Reward: -15
#
# Training episode 4820
# Time steps: 13, Penalties: 1, Reward: -1
#
# Training episode 4821
# Time steps: 16, Penalties: 2, Reward: -13
#
# Training episode 4822
# Time steps: 10, Penalties: 2, Reward: -7
#
# Training episode 4823
# Time steps: 11, Penalties: 1, Reward: 1
#
# Training episode 4824
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4825
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4826
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4827
# Time steps: 11, Penalties: 2, Reward: -8
#
# Training episode 4828
# Time steps: 14, Penalties: 3, Reward: -20
#
# Training episode 4829
# Time steps: 15, Penalties: 0, Reward: 6
#
# Training episode 4830
# Time steps: 22, Penalties: 2, Reward: -19
#
# Training episode 4831
# Time steps: 13, Penalties: 1, Reward: -1
#
# Training episode 4832
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4833
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 4834
# Time steps: 15, Penalties: 2, Reward: -12
#
# Training episode 4835
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 4836
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4837
# Time steps: 20, Penalties: 0, Reward: 1
#
# Training episode 4838
# Time steps: 27, Penalties: 3, Reward: -33
#
# Training episode 4839
# Time steps: 25, Penalties: 3, Reward: -31
#
# Training episode 4840
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4841
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 4842
# Time steps: 8, Penalties: 0, Reward: 13
#
# Training episode 4843
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4844
# Time steps: 23, Penalties: 3, Reward: -29
#
# Training episode 4845
# Time steps: 20, Penalties: 1, Reward: -8
#
# Training episode 4846
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4847
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4848
# Time steps: 29, Penalties: 3, Reward: -35
#
# Training episode 4849
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4850
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4851
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4852
# Time steps: 10, Penalties: 1, Reward: 2
#
# Training episode 4853
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4854
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4855
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4856
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4857
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 4858
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4859
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4860
# Time steps: 25, Penalties: 1, Reward: -13
#
# Training episode 4861
# Time steps: 10, Penalties: 1, Reward: 2
#
# Training episode 4862
# Time steps: 16, Penalties: 2, Reward: -13
#
# Training episode 4863
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4864
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4865
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4866
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4867
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4868
# Time steps: 13, Penalties: 2, Reward: -10
#
# Training episode 4869
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4870
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 4871
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4872
# Time steps: 8, Penalties: 0, Reward: 13
#
# Training episode 4873
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4874
# Time steps: 18, Penalties: 3, Reward: -24
#
# Training episode 4875
# Time steps: 19, Penalties: 2, Reward: -16
#
# Training episode 4876
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4877
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4878
# Time steps: 15, Penalties: 2, Reward: -12
#
# Training episode 4879
# Time steps: 20, Penalties: 0, Reward: 1
#
# Training episode 4880
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4881
# Time steps: 20, Penalties: 3, Reward: -26
#
# Training episode 4882
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4883
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 4884
# Time steps: 13, Penalties: 2, Reward: -10
#
# Training episode 4885
# Time steps: 20, Penalties: 2, Reward: -17
#
# Training episode 4886
# Time steps: 7, Penalties: 0, Reward: 14
#
# Training episode 4887
# Time steps: 20, Penalties: 1, Reward: -8
#
# Training episode 4888
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4889
# Time steps: 13, Penalties: 1, Reward: -1
#
# Training episode 4890
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 4891
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4892
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4893
# Time steps: 14, Penalties: 2, Reward: -11
#
# Training episode 4894
# Time steps: 17, Penalties: 4, Reward: -32
#
# Training episode 4895
# Time steps: 15, Penalties: 3, Reward: -21
#
# Training episode 4896
# Time steps: 21, Penalties: 1, Reward: -9
#
# Training episode 4897
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 4898
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 4899
# Time steps: 21, Penalties: 3, Reward: -27
#
# Training episode 4900
# Time steps: 17, Penalties: 2, Reward: -14
#
# Training episode 4901
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 4902
# Time steps: 6, Penalties: 0, Reward: 15
#
# Training episode 4903
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4904
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 4905
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4906
# Time steps: 13, Penalties: 1, Reward: -1
#
# Training episode 4907
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4908
# Time steps: 19, Penalties: 3, Reward: -25
#
# Training episode 4909
# Time steps: 20, Penalties: 1, Reward: -8
#
# Training episode 4910
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4911
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4912
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4913
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4914
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4915
# Time steps: 26, Penalties: 2, Reward: -23
#
# Training episode 4916
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 4917
# Time steps: 20, Penalties: 3, Reward: -26
#
# Training episode 4918
# Time steps: 21, Penalties: 4, Reward: -36
#
# Training episode 4919
# Time steps: 15, Penalties: 1, Reward: -3
#
# Training episode 4920
# Time steps: 27, Penalties: 5, Reward: -51
#
# Training episode 4921
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4922
# Time steps: 13, Penalties: 2, Reward: -10
#
# Training episode 4923
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 4924
# Time steps: 21, Penalties: 2, Reward: -18
#
# Training episode 4925
# Time steps: 22, Penalties: 2, Reward: -19
#
# Training episode 4926
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 4927
# Time steps: 31, Penalties: 4, Reward: -46
#
# Training episode 4928
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4929
# Time steps: 11, Penalties: 2, Reward: -8
#
# Training episode 4930
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 4931
# Time steps: 23, Penalties: 1, Reward: -11
#
# Training episode 4932
# Time steps: 18, Penalties: 1, Reward: -6
#
# Training episode 4933
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 4934
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4935
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 4936
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4937
# Time steps: 24, Penalties: 2, Reward: -21
#
# Training episode 4938
# Time steps: 7, Penalties: 0, Reward: 14
#
# Training episode 4939
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4940
# Time steps: 27, Penalties: 4, Reward: -42
#
# Training episode 4941
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 4942
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4943
# Time steps: 18, Penalties: 2, Reward: -15
#
# Training episode 4944
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4945
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4946
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4947
# Time steps: 21, Penalties: 0, Reward: 0
#
# Training episode 4948
# Time steps: 12, Penalties: 1, Reward: 0
#
# Training episode 4949
# Time steps: 11, Penalties: 2, Reward: -8
# Training episode 4950
# Time steps: 13, Penalties: 1, Reward: -1
#
# Training episode 4951
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4952
# Time steps: 20, Penalties: 2, Reward: -17
#
# Training episode 4953
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4954
# Time steps: 33, Penalties: 5, Reward: -57
#
# Training episode 4955
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4956
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4957
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 4958
# Time steps: 23, Penalties: 2, Reward: -20
#
# Training episode 4959
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4960
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4961
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4962
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4963
# Time steps: 16, Penalties: 0, Reward: 5
#
# Training episode 4964
# Time steps: 19, Penalties: 1, Reward: -7
#
# Training episode 4965
# Time steps: 20, Penalties: 0, Reward: 1
#
# Training episode 4966
# Time steps: 18, Penalties: 1, Reward: -6
#
# Training episode 4967
# Time steps: 25, Penalties: 1, Reward: -13
#
# Training episode 4968
# Time steps: 24, Penalties: 2, Reward: -21
#
# Training episode 4969
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4970
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4971
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 4972
# Time steps: 20, Penalties: 4, Reward: -35
#
# Training episode 4973
# Time steps: 30, Penalties: 1, Reward: -18
#
# Training episode 4974
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4975
# Time steps: 25, Penalties: 3, Reward: -31
#
# Training episode 4976
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 4977
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4978
# Time steps: 28, Penalties: 3, Reward: -34
#
# Training episode 4979
# Time steps: 19, Penalties: 0, Reward: 2
#
# Training episode 4980
# Time steps: 14, Penalties: 1, Reward: -2
#
# Training episode 4981
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 4982
# Time steps: 17, Penalties: 0, Reward: 4
#
# Training episode 4983
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 4984
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4985
# Time steps: 24, Penalties: 1, Reward: -12
#
# Training episode 4986
# Time steps: 14, Penalties: 0, Reward: 7
#
# Training episode 4987
# Time steps: 23, Penalties: 0, Reward: -2
#
# Training episode 4988
# Time steps: 11, Penalties: 0, Reward: 10
#
# Training episode 4989
# Time steps: 13, Penalties: 0, Reward: 8
#
# Training episode 4990
# Time steps: 16, Penalties: 1, Reward: -4
#
# Training episode 4991
# Time steps: 17, Penalties: 1, Reward: -5
#
# Training episode 4992
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4993
# Time steps: 9, Penalties: 0, Reward: 12
#
# Training episode 4994
# Time steps: 10, Penalties: 0, Reward: 11
#
# Training episode 4995
# Time steps: 22, Penalties: 1, Reward: -10
#
# Training episode 4996
# Time steps: 11, Penalties: 1, Reward: 1
#
# Training episode 4997
# Time steps: 12, Penalties: 0, Reward: 9
#
# Training episode 4998
# Time steps: 18, Penalties: 0, Reward: 3
#
# Training episode 4999
# Time steps: 14, Penalties: 2, Reward: -11
#
# Training episode 5000
# Time steps: 9, Penalties: 0, Reward: 12
# Training finished.

# %%
q_table[333]
# Out:
# array([-2.3470143 , -2.31153855, -2.3289116 , -2.35769712, -7.26776826,
#        -7.19915075])

# %%
initial_state = env.reset()
print(initial_state)
env.render()
# Out:
# 62
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
q_table[62]
# Out:
# array([-2.19096845, -2.27907431, -2.27141765, -2.25364375, -6.12575537,
#        -6.18658448])
